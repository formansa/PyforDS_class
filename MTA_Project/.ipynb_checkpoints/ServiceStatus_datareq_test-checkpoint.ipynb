# %%
# imports

import json
from html.parser import HTMLParser
import xml.etree.ElementTree as ET
 
import requests
import xmltodict

# %%
TARGET = 'servicestatus.json'
SOURCE = 'http://web.mta.info/status/serviceStatus.txt'
response = requests.get(SOURCE)
 
xml_string = response.text
xml_dict = xmltodict.parse(xml_string)

# %%
for i in xml_dict['service']['subway']['line']: print(i)
    
for i in xml_dict['service']['subway']['line']: print(i['name'], i['status'])
# Out:
# OrderedDict([('name', '123'), ('status', 'SERVICE CHANGE'), ('text', '<span class="TitleServiceChange" >Service Change</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:10PM\n                    </span><br/><br/>\n                  <P>[3] [SB] shuttle buses are detoured because of construction on Livonia Av between Mother Gaston Blvd and Junius St. </P>\n<P>Detour is as follows:</P>\n<P><STRONG>Towards Utica Av:</STRONG> Via Livonia Av, left on Pennsylvania Av, right on New Lots Av, right on Mother Gaston Blvd and regular route.</P>\n<P><STRONG>Towards New Lots Av:</STRONG>Â\xa0Via Livonia Av, right on Mother Gaston Blvd, left on New Lots Av and regular route.</P>\n<P>Allow additional travel time</P>\n                <br/><br/>\n              \n                    <span class="TitleDelay">Delays</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:07PM\n                    </span><br/><br/>\n                  <P>[1], [2] and [3] trains are running with slow speeds in both directionsÂ\xa0because of track maintenance from <STRONG>59 St-Columbus Circle</STRONG>Â\xa0to<STRONG> 72 St.</STRONG></P>\n<P>Allow additional travel time.</P>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168255);><b>[3] Downtown trains run local from 96 St to Times Sq-42 St</a><br/><br/><div id= 168255 class="plannedWorkDetail" ></b>Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  &bull;  Oct 28 - 30  &bull;  Nov 4 - 6<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168254);><b>[2] Downtown trains run local from 96 St to Times Sq-42 St</a><br/><br/><div id= 168254 class="plannedWorkDetail" ></b>Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  &bull;  Oct 28 - 30  &bull;  Nov 4 - 6<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(162679);><b>Weekend [2] [3] station closures and route changes</a><br/><br/><div id= 162679 class="plannedWorkDetail" ></b>Until Summer 2018<br><br>No service at Park Place, Wall St, Clark St and Hoyt St; use nearby [4] [5] stations<br><br>No [2] [3] service between Manhattan and Brooklyn; take the [4] or [5] instead.<br><br>Weekend service map for <a href=http://web.mta.info/nyct/service/pdf/FF_Clark_St_web_map.pdf target=_blank><font color=#0000FF><b><u>Lower Manhattan and Downtown Brooklyn</u></b></font></a><br><br></font>New timetables with Weekend Route Changes | [2] <a href=http://web.mta.info/nyct/service/pdf/t2cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [3] <a href=http://web.mta.info/nyct/service/pdf/t3cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [4] <a href=http://web.mta.info/nyct/service/pdf/t4cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [5] <a href=http://web.mta.info/nyct/service/pdf/t5cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a><br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168258);><b>[2] [5] Uptown trains run express from 3 Av-149 St to E 180 St</a><br/><br/><div id= 168258 class="plannedWorkDetail" ></b>Weekends, 3:45 AM Sat to 10 PM Sun, </font>Oct 21 - 22  & ...
# OrderedDict([('name', '456'), ('status', 'PLANNED WORK'), ('text', '<span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(170770);><b>[5] Trains run local in both directions between 125 St and Brooklyn Bridge</a><br/><br/><div id= 170770 class="plannedWorkDetail" ></b>Weekend, 10 PM Fri to 5 AM Mon, Oct 20 - 23<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(170768);><b>[4] Trains run local in both directions between 125 St and Brooklyn Bridge</a><br/><br/><div id= 170768 class="plannedWorkDetail" ></b>Weekend, 10 PM Fri to 5 AM Mon, Oct 20 - 23<br><br></font>&bull; Please allow additional travel time.<br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168268);><b>[4] No trains between Utica Av and New Lots Av</a><br/><br/><div id= 168268 class="plannedWorkDetail" >[SB] Free shuttle buses provide alternate service<br></b>Weekends, </font>11:30 PM Fri to 5 AM Mon, Oct 20 - 23  &bull;  Oct 27 - 30<br><br><b>[4]</b> service operates between <b>Woodlawn</b> and <b>Utica Av</b>.<br><br>[SB] Buses operate between <b>Utica Av</b> and <b>New Lots Av</b>,<i> making all stops</i>.<br>  &bull; Transfer between [4] trains and [SB] buses at Utica Av.<br><br><font size=3><b><a style="cursor:pointer; text-decoration:underline;" onclick=ShowHide(1682680);>Show Shuttle Bus Stops</a></b></font><div id="1682680"; style="display:none;"><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=3 rules=rows frame=hsides><tr bgcolor=#FAF8CC><td> [4] <b>Station</b><td><b>Shuttle Bus Stop</b><tr><td>Utica Av  [ad] [4]</font>  <td>Eastern Pkwy at Utica Av<tr><td>Sutter Av<td>E 98 St at Sutter Av<tr><td>Saratoga Av<td>Livonia Av at Saratoga Av<tr><td rowspan=2>Rockaway Av<td>Livonia Av at Chester Av<tr><td>Livonia Av at Osborn St<tr><td>Junius St<td>Livonia Av at Sackman St<tr><td>Pennsylvania Av<td>Livonia Av at Pennsylvania Av<tr><td>Van Siclen Av<td>Livonia Av at Van Siclen Av<tr><td>New Lots Av<td>Livonia Av at Jerome St</table></font></div><br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168258);><b>[2] [5] Uptown trains run express from 3 Av-149 St to E 180 St</a><br/><br/><div id= 168258 class="plannedWorkDetail" ></b>Weekends, 3:45 AM Sat to 10 PM Sun, </font>Oct 21 - 22  &bull;  Oct 28 - 29<br> <br>For service <i>to</i> Jackson, Prospect, Intervale Avs, Simpson, Freeman, 174 Sts and E Tremont Av, <br>take the <b>[2]</b> or <b>[5]</b> to E 180 St and transfer to a Manhattan-bound<b> [2] </b>or <b>[5]</b>.<br><br>For service <i>from</i> these stations, take the <b>[2]</b> or <b>[5]</b> to 149 St-Grand Concourse and transfer to an<br>uptown [2] or [5].<br><br></font><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=5 rules=none frame=box><td>  [ad]  <td><font size=1>This service change affects one or more ADA accessible stations. Please call 511 for help with planning<br>your trip. If you are deaf or hard of hearing, use your preferred relay service provider or the free 711 relay.  </font></table><br><b><br></div></b><br/>\n                <br/><br/>'), ('Date', '10/21/2017'), ('Time', '7:12PM')])
# OrderedDict([('name', '7'), ('status', 'PLANNED WORK'), ('text', '<span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168274);><b>[7] Flushing-bound trains skip 82, 90, 103 and 111 Sts</a><br/><br/><div id= 168274 class="plannedWorkDetail" ></b>Weekend, 3:45 AM to 10 PM, Saturday, Oct 21 <br><br>For service <i>to </i>these stations, take the [7] to Junction Blvd or Willets Point and transfer to a <br>Hudson Yards-bound [7].<br><br>For service <i>from </i>these stations, take the [7] to Junction Blvd or 74 St and transfer to a Flushing-bound [7].<br><b><br></div></b><br/>\n                <br/><br/>'), ('Date', '10/21/2017'), ('Time', '7:12PM')])
# OrderedDict([('name', 'ACE'), ('status', 'DELAYS'), ('text', '<span class="TitleDelay">Delays</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:47PM\n                    </span><br/><br/>\n                  <P>[A][C] and [D] trains are running at slow speeds in both directions because of track maintenance at <STRONG>72</STRONG> <STRONG>St.</STRONG> </P>\n<P>Allow additional travel time. </P>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168361);><b>[E] Jamaica Center-bound trains skip Spring St and 23 St</a><br/><br/><div id= 168361 class="plannedWorkDetail" ></b>Weekends, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23  &bull;  Oct 27 - 30<br><br></font>For service <i>to </i>these stations, take the [E] to W 4 St or 34 St-Penn Station <br>and transfer to a downtown [A] <i>local</i>, </font>[C] or [E].<br><br>For service <i>from </i>these stations, take the [A] [C] or [E] to 14 St <br>or Canal St and transfer to a Jamaica Center-bound [E].<br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168351);><b>[C] No trains between 145 St and 168 St<br clear=left>[A] trains provide alternate service</a><br/><br/><div id= 168351 class="plannedWorkDetail" ></b><a href=http://advisory.mtanyct.info/pdf_files/ServiceGuide.pdf target=_blank><font color=#0000FF><b><u>Weekend</u></b></font></a>, Saturday <i>and</i> Sunday, Oct 21 - 22<br><br></font>[C] service operates between <b>145 St</b> and <b>Euclid Av</b>.<br>[A] trains make <i>local</i> stops between </font><b>145 St</b> and <b>168 St</b>.<br><br>&bull; Transfer between trains at 125 St (across the platform) or 145 St.<br><br><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=5 rules=none frame=box><td>  [ad]  <td><font size=1>This service change affects one or more ADA accessible stations. Please call 511 for help with planning<br>your trip. If you are deaf or hard of hearing, use your preferred relay service provider or the free 711 relay.  </font></table><br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168367);><b>[C] Uptown trains skip 72, 81, 86, 96, 103, 110 and 116 Sts</a><br/><br/><div id= 168367 class="plannedWorkDetail" ></b><a href=http://advisory.mtanyct.info/pdf_files/ServiceGuide.pdf target=_blank><font color=#0000FF><b><u>Weekend</u></b></font></a>, Saturday <i>and</i> Sunday, Oct 21 - 22<br><br>For service <i>to</i> these stations, take the [C] to 125 St and transfer to a downtown [A] [C] or [D]*.<br><br>For service<i> from</i> these stations, take the [A] [C] or [D] to 59 St-Columbus Circle and transfer<br>to an uptown [C].<br><br><i>*This detour has taken into account additional planned service changes.<br></i><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168359);><b>[C] Uptown trains skip Spring St, 23 St and 50 St</a><br/><br/><div id= 168359 class="plannedWorkDetail" ></b><a href=http://advisory.mtanyct.info/pdf_files/ServiceGuide.pdf target=_blank><font color=#0000FF><b><u>Weekends</u></b></font></a>, Saturday <i>and </i>Sunday, Oct 21 - 22  &bull;  Oct 28 - 29<br><br></font>For service <i>to</i> Spring and 23 Sts, take the [C] to W 4 or 34 St-Penn Station<br>and transfer to a downtown [C] or [E].<br><br>For service <i>to</i> 50 St, transfer to the [E] at 42 St/Port Author ...
# OrderedDict([('name', 'BDFM'), ('status', 'DELAYS'), ('text', '<span class="TitleDelay">Delays</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:47PM\n                    </span><br/><br/>\n                  <P>[A][C] and [D] trains are running at slow speeds in both directions because of track maintenance at <STRONG>72</STRONG> <STRONG>St.</STRONG> </P>\n<P>Allow additional travel time. </P>\n                <br/><br/>\n              \n                    <span class="TitleDelay">Delays</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:06PM\n                    </span><br/><br/>\n                  <P>Southbound [D], [N] and [R] trains are running with slow speeds because of track maintenance from <STRONG>Prospect Av</STRONG> to <STRONG>53 St</STRONG> <STRONG>(BKLYN).</STRONG> </P>\n<P>Expect delays in both directions. </P>\n<P>Allow additional travel time.</P>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168364);><b>[F] No trains between Church Av and Stillwell Av</a><br/><br/><div id= 168364 class="plannedWorkDetail" >[SB] Free shuttle buses provide alternate service<br></b>Weekend, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23<br><br></font>[F] service operates between <b>179 St</b> and <b>Church Av</b>.<br><br>[SB] Buses operate between <b>Church Av</b> and <b>Stillwell Av*</b>, stopping at Ditmas Av, 18 Av, Avenue I, <br>Bay Pkwy, Avenue N, Avenue P, Kings Hwy, Avenue U, Avenue X, Neptune Av and W 8 St.<br><br>&bull; Transfer between [F] trains and [SB] buses at Church Av.<br><br>For direct service between Coney Island and Manhattan/Downtown Brooklyn, <br>take the <b>[D]</b> <b>[N] </b>or <b>[Q]</b> instead.<br><br>&bull; Transfer between [D] [N] [Q] trains and [SB] buses at Stillwell Av.<br>&bull; Transfer between [Q] trains and [SB] buses at West 8 St.<br><br><font size=3><b><a style="cursor:pointer; text-decoration:underline;" onclick=ShowHide(1683640);>Show Shuttle Bus Stops</a></b></font><div id="1683640"; style="display:none;"><br><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=3 rules=rows frame=hsides><tr bgcolor=#FAF8CC><td><b>Station</b></td><td>[SB] <b>Shuttle Bus Stop</b></td><td><b>Bus Stop</b><tr><td>Church Av  [ad] [FS] [GS] <td>McDonald Av at Church Av <td><b>B67</b><tr><td>Ditmas Av<td>McDonald Av at Ditmas Av<td>&mdash;<tr><td>18 Av<td>McDonald Av at 18 Av<td>&mdash;<tr><td>Avenue I<td>McDonald Av at Avenue I<td>&mdash;<tr><td>Bay Pkwy<td>McDonald Av at Bay Pkwy<td>&mdash;<tr><td rowspan=2>Avenue N<td>McDonald Av at 24 Av (to Stillwell Av)<tr><td>McDonald Av at Ave N (to Church Av)<td>&mdash;<tr><td>Avenue P<td>McDonald Av at Avenue P<td>&mdash;<tr><td>Kings Hwy<td>McDonald Av at Kings Hwy<td>&mdash;<tr><td>Avenue U<td>McDonald Av at Avenue U<td>&mdash;<tr><td rowspan=2>Avenue X<td>Shell Rd at Avenue X (to Stillwell Av)<td><b>B4</b><tr><td>McDonald Av at Avenue X (to Church Av)<td>&mdash;<tr><td rowspan=2>Neptune Av<td>Shell Rd at Neptune Av (to Stillwell Av)<td>&mdash;<tr><td>W 6 St at station entrance (to Church Av)<td>&mdash;<tr><td>W 8 St [Q]<td>Surf Av at W 8 St<td><b>B36</b><tr><td>Stillwell Av [ad] [DS] [NS] [QS]<td>Stillwell Av at Surf Av<td><b>B36</b></table></div> <br><br><i>*From 8 AM to 10 PM Saturday and Sunday, some buses will only operate between Church Av and <br>Kings Hwy.<br><br></i><b>Note</b>: Manhattan-bound platforms at Avenue U, Avenue P, Avenue N, Bay Pkwy  and Avenue I are closed for renovation.<br></font><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168362);><b>[F] Jamaica-bound trains skip  ...
# OrderedDict([('name', 'G'), ('status', 'GOOD SERVICE'), ('text', None), ('Date', None), ('Time', None)])
# OrderedDict([('name', 'JZ'), ('status', 'PLANNED WORK'), ('text', '<span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168476);><b>[J] No trains between Crescent St and Jamaica Center</a><br/><br/><div id= 168476 class="plannedWorkDetail" >[E] trains and [SB] free shuttle buses provide alternate service<br></b>Weekend, 3:45 AM Sat to 10 PM Sun, Oct 21 - 22<br><br>[J] Service operates between <b>Broad St</b> and <b>Crescent St</b>.<br><br>[SB] Buses make all [J] stops between <b>Crescent St</b> and <b>121 St</b> and connect with the <br>[E] at <b>Jamaica-Van Wyck</b>.<br><br><table class=plannedworkTableStyle  width=80%><tr><td><font size=3><b>Travel Alternatives</b></font><td align=right>[TP]</table><br></font>For service between <b>Crescent St</b> and <b>121 St</b>, take a [SB] bus.<br>&bull; Transfer between [J] trains and [SB] buses at </font><b>Crescent St</b>.<br><br>For <b>Sutphin Blvd/Archer Av</b> and <b>Jamaica Center</b>, take the [E] instead.<br>&bull; Transfer between [E] trains and [SB] buses a</font>t <b>Jamaica-Van Wyck</b>.<br><br><font size=3><b><a style="cursor:pointer; text-decoration:underline;" onclick=ShowHide(1684760);>Show Shuttle Bus Stops</a></b></font><div id="1684760"; style="display:none;"><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=3 rules=rows frame=hsides><tr><td bgcolor=#FAF8CC><b>Station</b><td bgcolor=#FAF8CC><b>Shuttle Bus Stop</b><td bgcolor=#FAF8CC><b>Bus</b><tr><td>Crescent St  [J]<td>Fulton St at Crescent St<td> &mdash;<tr><td rowspan=2>Cypress Hills<td>Jamaica Av at Hemlock St (to Jamaica-Van Wyck)<td><b>Q56</b><tr><td>Crescent St at Jamaica Av (to Crescent St)<td> &mdash;<tr><td rowspan=2>75 St-Elderts Ln<td>Jamaica Av at 75 St (to Jamaica-Van Wyck)<td><b>Q56</b><tr><td>Jamaica Av at Dexter Ct (to Crescent St)<td><b>Q56</b><tr><td rowspan=2>85 St-Forest Pkwy<td>Jamaica Av at 85 St (to Jamaica-Van Wyck)<td><b>Q56</b><tr><td>Jamaica Av at 86 St (to Crescent St)<td><b>Q56</b><tr><td>Woodhaven Blvd<td>Jamaica Av at Woodhaven Blvd<td><b>Q56</b><tr><td>104 St<td>Jamaica Av at 104 St<td><b>Q56</b><tr><td>111 St<td>Jamaica Av at 111 St<td><b>Q56</b><tr><td>121 St<td>Jamaica Av at 121 St<td><b>Q56</b></font><tr><td>Jamaica-Van Wyck [E]  </font><td>Van Wyck Service Rd at 89 Av<td> &mdash;</table></div><br><br></font><b><i>Alternate travel note:<br></b></i>For JFK Airport <a href=http://www.panynj.gov/airports/jfk-airtrain.html target=_blank><font color=#0000FF><b><u>AirTrain</u></b></font></a>, use the [A] at Howard Beach-JFK via transfer at Broadway Junction.<br><br><b>Note:</b> Manhattan-bound platforms at 121 St and 104 St are closed for renovation.<br><br><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=5 rules=none frame=box><td>  [ad]  <td><font size=1>This service change affects one or more ADA accessible stations. Please call 511 for help with planning<br>your trip. If you are deaf or hard of hearing, use your preferred relay service provider or the free 711 relay.  </font></table><br><b><br></div></b><br/>\n                <br/><br/>'), ('Date', '10/21/2017'), ('Time', '7:12PM')])
# OrderedDict([('name', 'L'), ('status', 'DELAYS'), ('text', '<span class="TitleDelay">Delays</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:39PM\n                    </span><br/><br/>\n                  <P>[L] trains are running with delays in both directions because of switch problems at <STRONG>Canarsie-Rockaway Pkwy. </STRONG></P>\n<P>Allow additional travel time.</P>\n                <br/><br/>'), ('Date', '10/21/2017'), ('Time', '6:39PM')])
# OrderedDict([('name', 'NQR'), ('status', 'DELAYS'), ('text', '<span class="TitleDelay">Delays</span>\n                    <span class="DateStyle">\n                    &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:06PM\n                    </span><br/><br/>\n                  <P>Southbound [D], [N] and [R] trains are running with slow speeds because of track maintenance from <STRONG>Prospect Av</STRONG> to <STRONG>53 St</STRONG> <STRONG>(BKLYN).</STRONG> </P>\n<P>Expect delays in both directions. </P>\n<P>Allow additional travel time.</P>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168473);><b>[R] Bay Ridge-bound trains run express from Atlantic Av-Barclays Ctr to 59 St, Brooklyn</a><br/><br/><div id= 168473 class="plannedWorkDetail" ></b>Weekend, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23<br><br>Trains stop at 36 St.<br><br>For service <i>to</i> Union St, 4 Av-9 St and 25 St, take the [R] to 36 St and transfer to a <br><i>local</i> Manhattan-bound [D] [N] or [R].<br><br>For service <i>from</i> these stations, take the [D] [N] or [R] to Atlantic Av-Barclays Ctr and transfer <br>to a Bay Ridge-bound [R].<br><br>For service <i>to</i> 45 St and 53 St, take the [R] to 59 St and transfer to a Manhattan-bound [N] <i>local</i> or [R].<br><br>For service <i>from</i> these stations, take the [N] or [R] to 36 St and transfer to a Bay Ridge-bound [R].<br><br><b>Note:</b> Prospect Av is closed for renovation.<br><b><br></div></b><br/>\n                <br/><br/>\n              \n                    <span class="TitlePlannedWork" >Planned Work</span>\n                    <br/>\n                  <a class="plannedWorkDetailLink" onclick=ShowHide(168469);><b>[N] Astoria-bound trains skip 39 Av, 36 Av, Broadway and 30 Av</a><br/><br/><div id= 168469 class="plannedWorkDetail" ></b>Weekend, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23<br><br>For service<i> to</i> these stations, take the [N] to Astoria Blvd and transfer to a Coney Island-bound [N].<br><br>For service<i> from </i>these stations, take the [N] to Queensboro Plaza and transfer to an Astoria-bound [N].<br><b><br></div></b><br/>\n                <br/><br/>'), ('Date', '10/21/2017'), ('Time', '6:06PM')])
# OrderedDict([('name', 'S'), ('status', 'GOOD SERVICE'), ('text', None), ('Date', None), ('Time', None)])
# OrderedDict([('name', 'SIR'), ('status', 'GOOD SERVICE'), ('text', None), ('Date', None), ('Time', None)])
# 123 SERVICE CHANGE
# 456 PLANNED WORK
# 7 PLANNED WORK
# ACE DELAYS
# BDFM DELAYS
# G GOOD SERVICE
# JZ PLANNED WORK
# L DELAYS
# NQR DELAYS
# S GOOD SERVICE
# SIR GOOD SERVICE

# %%
class MyHTMLParser(HTMLParser):

    
    def handle_data(self, data):
        print("Data: ", data)
        
    def handle_starttag(self, tag, attrs):
        if tag in pass_start_tags:
            pass
        else: 
            
            print("Start tag: ", tag)
            for attr in attrs:
                print("   attr: ", attr)
        

pass_start_tags = ['br', 'strong']
parser = MyHTMLParser()

parser.feed(xml_dict['service']['subway']['line'][0]['text'])
# Out:
# Start tag:  span
#    attr:  ('class', 'TitleServiceChange')
# Data:  Service Change
# Data:
#
# Start tag:  span
#    attr:  ('class', 'DateStyle')
# Data:
#                      Posted: 10/21/2017  6:10PM
#
# Data:
#
# Start tag:  p
# Data:  [3] [SB] shuttle buses are detoured because of construction on Livonia Av between Mother Gaston Blvd and Junius St.
# Data:
#
# Start tag:  p
# Data:  Detour is as follows:
# Data:
#
# Start tag:  p
# Data:  Towards Utica Av:
# Data:   Via Livonia Av, left on Pennsylvania Av, right on New Lots Av, right on Mother Gaston Blvd and regular route.
# Data:
#
# Start tag:  p
# Data:  Towards New Lots Av:
# Data:  Â Via Livonia Av, right on Mother Gaston Blvd, left on New Lots Av and regular route.
# Data:
#
# Start tag:  p
# Data:  Allow additional travel time
# Data:
#
# Data:
#
#
# Start tag:  span
#    attr:  ('class', 'TitleDelay')
# Data:  Delays
# Data:
#
# Start tag:  span
#    attr:  ('class', 'DateStyle')
# Data:
#                      Posted: 10/21/2017  6:07PM
#
# Data:
#
# Start tag:  p
# Data:  [1], [2] and [3] trains are running with slow speeds in both directionsÂ because of track maintenance from
# Data:  59 St-Columbus Circle
# Data:  Â to
# Data:   72 St.
# Data:
#
# Start tag:  p
# Data:  Allow additional travel time.
# Data:
#
# Data:
#
#
# Start tag:  span
#    attr:  ('class', 'TitlePlannedWork')
# Data:  Planned Work
# Data:
#
# Data:
#
# Start tag:  a
#    attr:  ('class', 'plannedWorkDetailLink')
#    attr:  ('onclick', 'ShowHide(168255);')
# Start tag:  b
# Data:  [3] Downtown trains run local from 96 St to Times Sq-42 St
# Start tag:  div
#    attr:  ('id', '168255')
#    attr:  ('class', 'plannedWorkDetail')
# Data:  Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  •  Oct 28 - 30  •  Nov 4 - 6
# Data:  • Please allow additional travel time.
# Start tag:  b
# Data:
#
# Data:
#
#
# Start tag:  span
#    attr:  ('class', 'TitlePlannedWork')
# Data:  Planned Work
# Data:
#
# Data:
#
# Start tag:  a
#    attr:  ('class', 'plannedWorkDetailLink')
#    attr:  ('onclick', 'ShowHide(168254);')
# Start tag:  b
# Data:  [2] Downtown trains run local from 96 St to Times Sq-42 St
# Start tag:  div
#    attr:  ('id', '168254')
#    attr:  ('class', 'plannedWorkDetail')
# Data:  Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  •  Oct 28 - 30  •  Nov 4 - 6
# Data:  • Please allow additional travel time.
# Start tag:  b
# Data:
#
# Data:
#
#
# Start tag:  span
#    attr:  ('class', 'TitlePlannedWork')
# Data:  Planned Work
# Data:
#
# Data:
#
# Start tag:  a
#    attr:  ('class', 'plannedWorkDetailLink')
#    attr:  ('onclick', 'ShowHide(162679);')
# Start tag:  b
# Data:  Weekend [2] [3] station closures and route changes
# Start tag:  div
#    attr:  ('id', '162679')
#    attr:  ('class', 'plannedWorkDetail')
# Data:  Until Summer 2018
# Data:  No service at Park Place, Wall St, Clark St and Hoyt St; use nearby [4] [5] stations
# Data:  No [2] [3] service between Manhattan and Brooklyn; take the [4] or [5] instead.
# Data:  Weekend service map for
# Start tag:  a
#    attr:  ('href', 'http://web.mta.info/nyct/service/pdf/FF_Clark_St_web_map.pdf')
#    attr:  ('target', '_blank')
# Start tag:  font
#    attr:  ('color', '#0000FF')
# Start tag:  b
# Start tag:  u
# Data:  Lower Manhattan and Downtown Brooklyn
# Data:  New timetables with Weekend Route Changes | [2]
# Start tag:  a
#    attr:  ('href', 'http://web.mta.info/nyct/service/pdf/t2cur.pdf')
#    attr:  ('target', '_blank')
# Start tag:  font
#    attr:  ('color', '#0000FF')
# Start tag:  b
# Start tag:  u
# Data:  pdf
# Data:   | [3]
# Start tag:  a
#    attr:  ('href', 'http://web.mta.info/nyct/service/pdf/t3cur.pdf')
#    attr:  ('target', '_blank')
# Start tag:  font
#    attr:  ('color', '#0000FF')
# Start tag:  b
# Start tag:  u
# Data:  pdf
# Data:   | [4]
# Start tag:  a
#    attr:  ('href', 'http://web.mta.info/nyct/service/pdf/t4cur.pdf')
#    attr:  ('target', '_blank')
# Start tag:  font
#    attr:  ('color', '#0000FF')
# Start tag:  b
# Start tag:  u
# Data:  pdf
# Data:   | [5]
# Start tag:  a
#    attr:  ('href', 'http://web.mta.info/nyct/service/pdf/t5cur.pdf')
#    attr:  ('target', '_blank')
# Start tag:  font
#    attr:  ('color', '#0000FF')
# Start tag:  b
# Start tag:  u
# Data:  pdf
# Start tag:  b
# Data:
#
# Data:
#
#
# Start tag:  span
#    attr:  ('class', 'TitlePlannedWork')
# Data:  Planned Work
# Data:
#
# Data:
#
# Start tag:  a
#    attr:  ('class', 'plannedWorkDetailLink')
#    attr:  ('onclick', 'ShowHide(168258);')
# Start tag:  b
# Data:  [2] [5] Uptown trains run express from 3 Av-149 St to E 180 St
# Start tag:  div
#    attr:  ('id', '168258')
#    attr:  ('class', 'plannedWorkDetail')
# Data:  Weekends, 3:45 AM Sat to 10 PM Sun,
# Data:  Oct 21 - 22  •  Oct 28 - 29
# Data:
# Data:  For service
# Start tag:  i
# Data:  to
# Data:   Jackson, Prospect, Intervale Avs, Simpson, Freeman, 174 Sts and E Tremont Av,
# Data:  take the
# Start tag:  b
# Data:  [2]
# Data:   or
# Start tag:  b
# Data:  [5]
# Data:   to E 180 St and transfer to a Manhattan-bound
# Start tag:  b
# Data:   [2]
# Data:  or
# Start tag:  b
# Data:  [5]
# Data:  .
# Data:  For service
# Start tag:  i
# Data:  from
# Data:   these stations, take the
# Start tag:  b
# Data:  [2]
# Data:   or
# Start tag:  b
# Data:  [5]
# Data:   to 149 St-Grand Concourse and transfer to an
# Data:  uptown [2] or [5].
# Start tag:  table
#    attr:  ('class', 'plannedworkTableStyle')
#    attr:  ('border', '1')
#    attr:  ('cellspacing', '1')
#    attr:  ('cellpadding', '5')
#    attr:  ('rules', 'none')
#    attr:  ('frame', 'box')
# Start tag:  td
# Data:    [ad]
# Start tag:  td
# Start tag:  font
#    attr:  ('size', '1')
# Data:  This service change affects one or more ADA accessible stations. Please call 511 for help with planning
# Data:  your trip. If you are deaf or hard of hearing, use your preferred relay service provider or the free 711 relay.
# Start tag:  b
# Data:
#
# Data:
#
#
# Start tag:  span
#    attr:  ('class', 'TitlePlannedWork')
# Data:  Planned Work
# Data:
#
# Data:
#
# Start tag:  a
#    attr:  ('class', 'plannedWorkDetailLink')
#    attr:  ('onclick', 'ShowHide(168256);')
# Start tag:  b
# Data:  [1] Van Cortlandt Park-bound trains skip 50 St, 59 St and 66
# Data:   St
# Start tag:  div
#    attr:  ('id', '168256')
#    attr:  ('class', 'plannedWorkDetail')
# Data:  Weekends, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23  •  Oct 27 - 30  •  Nov 3 - 6
# Data:  For service
# Start tag:  i
# Data:   to
# Data:   these stations, take the
# Start tag:  b
# Data:  [1]
# Data:   to 72 St and
# Data:  transfer to a downtown
# Start tag:  b
# Data:  [1]
# Data:
# Start tag:  b
# Data:  [2]
# Data:  * or [3]*.
# Data:  For service
# Start tag:  i
# Data:  from
# Data:   these stations, take the
# Start tag:  b
# Data:  [1]
# Data:
# Start tag:  b
# Data:  [2]
# Data:   or [3] to Times Sq-42 St and transfer to a
# Data:  Van Cortlandt Park-bound
# Start tag:  b
# Data:  [1]
# Data:  .
# Start tag:  i
# Data:  *This detour has taken into account additional planned service changes.
# Start tag:  b
# Data:

# %%
root = ET.fromstring(xml_string)
print(type(root))
for i in root[2][0]: print(i.tag,' --> ',i.text)
# Out:
# <class 'xml.etree.ElementTree.Element'>
# name  -->  123
# status  -->  SERVICE CHANGE
# text  -->
#                     <span class="TitleServiceChange" >Service Change</span>
#                     <span class="DateStyle">
#                     &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:10PM
#                     </span><br/><br/>
#                   <P>[3] [SB] shuttle buses are detoured because of construction on Livonia Av between Mother Gaston Blvd and Junius St. </P>
# <P>Detour is as follows:</P>
# <P><STRONG>Towards Utica Av:</STRONG> Via Livonia Av, left on Pennsylvania Av, right on New Lots Av, right on Mother Gaston Blvd and regular route.</P>
# <P><STRONG>Towards New Lots Av:</STRONG>Â Via Livonia Av, right on Mother Gaston Blvd, left on New Lots Av and regular route.</P>
# <P>Allow additional travel time</P>
#                 <br/><br/>
#
#                     <span class="TitleDelay">Delays</span>
#                     <span class="DateStyle">
#                     &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:07PM
#                     </span><br/><br/>
#                   <P>[1], [2] and [3] trains are running with slow speeds in both directionsÂ because of track maintenance from <STRONG>59 St-Columbus Circle</STRONG>Â to<STRONG> 72 St.</STRONG></P>
# <P>Allow additional travel time.</P>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168255);><b>[3] Downtown trains run local from 96 St to Times Sq-42 St</a><br/><br/><div id= 168255 class="plannedWorkDetail" ></b>Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  &bull;  Oct 28 - 30  &bull;  Nov 4 - 6<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168254);><b>[2] Downtown trains run local from 96 St to Times Sq-42 St</a><br/><br/><div id= 168254 class="plannedWorkDetail" ></b>Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  &bull;  Oct 28 - 30  &bull;  Nov 4 - 6<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(162679);><b>Weekend [2] [3] station closures and route changes</a><br/><br/><div id= 162679 class="plannedWorkDetail" ></b>Until Summer 2018<br><br>No service at Park Place, Wall St, Clark St and Hoyt St; use nearby [4] [5] stations<br><br>No [2] [3] service between Manhattan and Brooklyn; take the [4] or [5] instead.<br><br>Weekend service map for <a href=http://web.mta.info/nyct/service/pdf/FF_Clark_St_web_map.pdf target=_blank><font color=#0000FF><b><u>Lower Manhattan and Downtown Brooklyn</u></b></font></a><br><br></font>New timetables with Weekend Route Changes | [2] <a href=http://web.mta.info/nyct/service/pdf/t2cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [3] <a href=http://web.mta.info/nyct/service/pdf/t3cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [4] <a href=http://web.mta.info/nyct/service/pdf/t4cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [5] <a href=http://web.mta.info/nyct/service/pdf/t5cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a><br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168258);><b>[2] [5] Uptown trains run express from 3 Av-149 St to E 180 St</a><br/><br/><div id= 168258 class="plannedWorkDetail" ></b>Weekends, 3:45 AM Sat to 10 PM Sun, </font>Oct 21 - 22  &bull;  Oct 28 - 29<br> <br>For service <i>to</i> Jackson, Prospect, Intervale Avs, Simpson, Freeman, 174 Sts and E Tremont Av, <br>take the <b>[2]</b> or <b>[5]</b> to E 180 St and transfer to a Manhattan-bound<b> [2] </b>or <b>[5]</b>.<br><br>For service <i>from</i> these stations, take the <b>[2]</b> or <b>[5]</b> to 149 St-Grand Concourse and transfer to an<br>uptown [2] or [5].<br><br></font><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=5 rules=none frame=box><td>  [ad]  <td><font size=1>This service change affects one or more ADA accessible stations. Please call 511 for help with planning<br>your trip. If you are deaf or hard of hearing, use your preferred relay service provider or the free 711 relay.  </font></table><br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168256);><b>[1] Van Cortlandt Park-bound trains skip 50 St, 59 St and 66</font> St</a><br/><br/><div id= 168256 class="plannedWorkDetail" ></b>Weekends, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23  &bull;  Oct 27 - 30  &bull;  Nov 3 - 6<br><br>For service<i> to</i> these stations, take the <b>[1]</b> to 72 St and </font>transfer to a downtown <b>[1]</b> </font><b>[2]</b>* or [3]*.<br><br>For service <i>from</i> these stations, take the <b>[1]</b> </font><b>[2]</b> or [3] to Times Sq-42 St and transfer to a <br>Van Cortlandt Park-bound <b>[1]</b>.<br><br><i>*This detour has taken into account additional planned service changes.<br></i><b><br></div></b><br/>
#                 <br/><br/>
#
# Date  -->  10/21/2017
# Time  -->   6:10PM

# %%
# try to list lines and current status

len_num = len(root[2])
num_lines = range(0,(len_num - 1))


lines_len = list(range(0,len(root[2]) -1 ))
for ea in lines_len:
    print(root[2][int(ea)][0].text, ' --> ', root[2][ea][1].text)
# Out:
# 123  -->  SERVICE CHANGE
# 456  -->  PLANNED WORK
# 7  -->  PLANNED WORK
# ACE  -->  DELAYS
# BDFM  -->  DELAYS
# G  -->  GOOD SERVICE
# JZ  -->  PLANNED WORK
# L  -->  DELAYS
# NQR  -->  DELAYS
# S  -->  GOOD SERVICE

# %%
# try to deal with service descirption text
print(root[2][0][2].text)

for i in root[2][0][2]:
    print(i.attrib)
# Out:
#                     <span class="TitleServiceChange" >Service Change</span>
#                     <span class="DateStyle">
#                     &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:10PM
#                     </span><br/><br/>
#                   <P>[3] [SB] shuttle buses are detoured because of construction on Livonia Av between Mother Gaston Blvd and Junius St. </P>
# <P>Detour is as follows:</P>
# <P><STRONG>Towards Utica Av:</STRONG> Via Livonia Av, left on Pennsylvania Av, right on New Lots Av, right on Mother Gaston Blvd and regular route.</P>
# <P><STRONG>Towards New Lots Av:</STRONG>Â Via Livonia Av, right on Mother Gaston Blvd, left on New Lots Av and regular route.</P>
# <P>Allow additional travel time</P>
#                 <br/><br/>
#
#                     <span class="TitleDelay">Delays</span>
#                     <span class="DateStyle">
#                     &nbsp;Posted:&nbsp;10/21/2017&nbsp; 6:07PM
#                     </span><br/><br/>
#                   <P>[1], [2] and [3] trains are running with slow speeds in both directionsÂ because of track maintenance from <STRONG>59 St-Columbus Circle</STRONG>Â to<STRONG> 72 St.</STRONG></P>
# <P>Allow additional travel time.</P>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168255);><b>[3] Downtown trains run local from 96 St to Times Sq-42 St</a><br/><br/><div id= 168255 class="plannedWorkDetail" ></b>Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  &bull;  Oct 28 - 30  &bull;  Nov 4 - 6<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168254);><b>[2] Downtown trains run local from 96 St to Times Sq-42 St</a><br/><br/><div id= 168254 class="plannedWorkDetail" ></b>Weekends, 12:01 AM Sat to 5 AM Mon, Oct 21 - 23  &bull;  Oct 28 - 30  &bull;  Nov 4 - 6<br><br>&bull; Please allow additional travel time.<br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(162679);><b>Weekend [2] [3] station closures and route changes</a><br/><br/><div id= 162679 class="plannedWorkDetail" ></b>Until Summer 2018<br><br>No service at Park Place, Wall St, Clark St and Hoyt St; use nearby [4] [5] stations<br><br>No [2] [3] service between Manhattan and Brooklyn; take the [4] or [5] instead.<br><br>Weekend service map for <a href=http://web.mta.info/nyct/service/pdf/FF_Clark_St_web_map.pdf target=_blank><font color=#0000FF><b><u>Lower Manhattan and Downtown Brooklyn</u></b></font></a><br><br></font>New timetables with Weekend Route Changes | [2] <a href=http://web.mta.info/nyct/service/pdf/t2cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [3] <a href=http://web.mta.info/nyct/service/pdf/t3cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [4] <a href=http://web.mta.info/nyct/service/pdf/t4cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a> | [5] <a href=http://web.mta.info/nyct/service/pdf/t5cur.pdf target=_blank><font color=#0000FF><b><u>pdf</u></b></font></a><br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168258);><b>[2] [5] Uptown trains run express from 3 Av-149 St to E 180 St</a><br/><br/><div id= 168258 class="plannedWorkDetail" ></b>Weekends, 3:45 AM Sat to 10 PM Sun, </font>Oct 21 - 22  &bull;  Oct 28 - 29<br> <br>For service <i>to</i> Jackson, Prospect, Intervale Avs, Simpson, Freeman, 174 Sts and E Tremont Av, <br>take the <b>[2]</b> or <b>[5]</b> to E 180 St and transfer to a Manhattan-bound<b> [2] </b>or <b>[5]</b>.<br><br>For service <i>from</i> these stations, take the <b>[2]</b> or <b>[5]</b> to 149 St-Grand Concourse and transfer to an<br>uptown [2] or [5].<br><br></font><table class=plannedworkTableStyle  border=1 cellspacing=1 cellpadding=5 rules=none frame=box><td>  [ad]  <td><font size=1>This service change affects one or more ADA accessible stations. Please call 511 for help with planning<br>your trip. If you are deaf or hard of hearing, use your preferred relay service provider or the free 711 relay.  </font></table><br><b><br></div></b><br/>
#                 <br/><br/>
#
#                     <span class="TitlePlannedWork" >Planned Work</span>
#                     <br/>
#                   <a class="plannedWorkDetailLink" onclick=ShowHide(168256);><b>[1] Van Cortlandt Park-bound trains skip 50 St, 59 St and 66</font> St</a><br/><br/><div id= 168256 class="plannedWorkDetail" ></b>Weekends, 11:45 PM Fri to 5 AM Mon, Oct 20 - 23  &bull;  Oct 27 - 30  &bull;  Nov 3 - 6<br><br>For service<i> to</i> these stations, take the <b>[1]</b> to 72 St and </font>transfer to a downtown <b>[1]</b> </font><b>[2]</b>* or [3]*.<br><br>For service <i>from</i> these stations, take the <b>[1]</b> </font><b>[2]</b> or [3] to Times Sq-42 St and transfer to a <br>Van Cortlandt Park-bound <b>[1]</b>.<br><br><i>*This detour has taken into account additional planned service changes.<br></i><b><br></div></b><br/>
#                 <br/><br/>
